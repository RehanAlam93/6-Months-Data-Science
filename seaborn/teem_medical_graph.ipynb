# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\rehan\OneDrive\Desktop\Data Science\6-Months-Data-Science\pandas\Teen_Mental_Health_Dataset.csv')

# %%
data
# Out:
#       age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0      14    male                       7.9      Instagram          7.4
# 1      19  female                       1.9         TikTok          8.0
# 2      17  female                       1.3      Instagram          7.6
# 3      15    male                       7.4         TikTok          6.9
# 4      15  female                       4.7           Both          4.9
# ...   ...     ...                       ...            ...          ...
# 1195   18  female                       6.8      Instagram          6.6
# 1196   16    male                       2.3           Both          8.0
# 1197   14  female                       1.7           Both          8.7
# 1198   15    male                       3.9           Both          8.5
# 1199   16  female                       4.7         TikTok          6.5
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# ...

# %%
sns.histplot(data['age'])
plt.show()

# %%
sns.histplot(data['age'], kde=True, bins=20)
plt.show()

# %%
sns.scatterplot(x=data['sleep_hours'], y=data['screen_time_before_sleep'])
plt.show()

# %%
plt.scatter(data['platform_usage'],data['stress_level'])
plt.show()

# %%
sns.kdeplot(data=data,x='age',y='daily_social_media_hours')
plt.show()

# %%
sns.kdeplot(data=data,x='age',y='daily_social_media_hours', fill=True)
plt.show()

# %%
sns.kdeplot(data=data,x='age')
plt.show()

# %%
sns.relplot(x='platform_usage',y='screen_time_before_sleep',data=data)
plt.show()
