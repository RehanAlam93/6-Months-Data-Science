# %%
print("operating system module")
# Out:
# operating system module

# %%
import os

# %%
os.getcwd()  # current working directory
# Out:
# 'c:\\Users\\rehan\\OneDrive\\Desktop\\Data Science\\python\\os'

# %%
os.listdir(r'c:\\Users\\rehan\\OneDrive\\Desktop\\Data Science\\python\\os')    # find list of dir
# Out:
# ['osmodule.ipynb']

# %%
os.mkdir("dev")    # create a folder

# %%
os.makedirs(r"hello\hii\i\dev")   # multiple folder create

# %%
# os.remove(r"os\\dev")

# %%
os.chdir(r"C:\Users\rehan\OneDrive\Pictures\New folder")  # change current dir

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rehan\\OneDrive\\Pictures\\New folder'

# %%
os.rmdir(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os\dev")   # delete folder

# %%
# os.removedirs(r"C:\Users\rehan\Music\music")    # delete  dir

# %%
os.stat(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os\hello.txt")  # find info if file
# Out:
# os.stat_result(st_mode=33206, st_ino=17451448556127438, st_dev=3830161557, st_nlink=1, st_uid=0, st_gid=0, st_size=14, st_atime=1779879637, st_mtime=1779879636, st_ctime=1779879625)

# %%
os.startfile(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os\hello.txt") # start file

# %%
os.rename(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os",
          r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os hii.txt")  # change text

# %%
os.path.isfile(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os hii.txt\hello\hii")     # chek file is avaliable or not
# Out:
# False

# %%
os.path.isdir(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os hii.txt\hello\hii\i")  # dir avaliable or not
# Out:
# True

# %%
os.path.exists(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os hii.txt\hello\hii\i")  # is path exists or not
# Out:
# True

# %%
path1=r"C:\Windows\System32"   # join two path
path2=r"%userprofile%\OneDrive"
complete=os.path.join(path1,path2)
print(complete)
# Out:
# C:\Windows\System32\%userprofile%\OneDrive

# %%
os.listdir(r"C:\Windows\System32\%userprofile%\OneDrive")    # find list
# Out:
# []

# %%
os.path.getsize(r"C:\Users\rehan\OneDrive\Desktop\Data Science\python\os\osmodule.ipynb")   # find getsize in bit
# Out:
# 7343
