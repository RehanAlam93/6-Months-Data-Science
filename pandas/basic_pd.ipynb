# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import os

# %%
student_data = {
    "Student_ID": [
        101, 102, 103, 104, 105,
        106, 107, 108, 109, 110,
        111, 112, 113, 114, 115,
        116, 117, 118, 119, 120
    ],
    "Student_Name": [
        "Aarav", "Vivaan", "Aditya", "Krishna", "Arjun",
        "Rohan", "Karan", "Rahul", "Mohit", "Ankit",
        "Priya", "Neha", "Pooja", "Sneha", "Riya",
        "Simran", "Kavya", "Isha", "Meera", "Aditi"
    ],
    "Marks": [
        85, 78, 92, 88, 76,
        81, 95, 67, 89, 73,
        91, 84, 79, 87, 93,
        75, 82, 90, 86, 80
    ]
}

# %%
df=pd.DataFrame(student_data)  # create data frame from dictionary

# %%
df['Student_Name']  # access column by name
# Out:
# 0       Aarav
# 1      Vivaan
# 2      Aditya
# 3     Krishna
# 4       Arjun
# 5       Rohan
# 6       Karan
# 7       Rahul
# 8       Mohit
# 9       Ankit
# 10      Priya
# 11       Neha
# 12      Pooja
# 13      Sneha
# 14       Riya
# 15     Simran
# 16      Kavya
# 17       Isha
# 18      Meera
# 19      Aditi
# Name: Student_Name, dtype: str

# %%
df[['Student_Name']]  # access column by name and return as dataframe
# Out:
#    Student_Name
# 0         Aarav
# 1        Vivaan
# 2        Aditya
# 3       Krishna
# 4         Arjun
# 5         Rohan
# 6         Karan
# 7         Rahul
# 8         Mohit
# 9         Ankit
# 10        Priya
# 11         Neha
# 12        Pooja
# 13        Sneha
# 14         Riya
# 15       Simran
# 16        Kavya
# 17         Isha
# 18        Meera
# 19        Aditi

# %%
df['Student_ID']  # access column by name and return as series
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# 12    113
# 13    114
# 14    115
# 15    116
# 16    117
# 17    118
# 18    119
# 19    120
# Name: Student_ID, dtype: int64

# %%
df.head(10)   # find upper 10 data
# Out:
#    Student_ID Student_Name  Marks
# 0         101        Aarav     85
# 1         102       Vivaan     78
# 2         103       Aditya     92
# 3         104      Krishna     88
# 4         105        Arjun     76
# 5         106        Rohan     81
# 6         107        Karan     95
# 7         108        Rahul     67
# 8         109        Mohit     89
# 9         110        Ankit     73

# %%
df.tail()  # next lower
# Out:
#     Student_ID Student_Name  Marks
# 15         116       Simran     75
# 16         117        Kavya     82
# 17         118         Isha     90
# 18         119        Meera     86
# 19         120        Aditi     80

# %%
df.info()   # data set type and null value
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    20 non-null     int64
#  1   Student_Name  20 non-null     str
#  2   Marks         20 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 612.0 bytes

# %%
df.columns   # column name
# Out:
# Index(['Student_ID', 'Student_Name', 'Marks'], dtype='str')

# %%
df[['Marks']]  # access column by name
# Out:
#     Marks
# 0      85
# 1      78
# 2      92
# 3      88
# 4      76
# 5      81
# 6      95
# 7      67
# 8      89
# 9      73
# 10     91
# 11     84
# 12     79
# 13     87
# 14     93
# 15     75
# 16     82
# 17     90
# 18     86
# 19     80

# %%
df.drop('Student_ID',axis=1)   # drop column by name
# Out:
#    Student_Name  Marks
# 0         Aarav     85
# 1        Vivaan     78
# 2        Aditya     92
# 3       Krishna     88
# 4         Arjun     76
# 5         Rohan     81
# 6         Karan     95
# 7         Rahul     67
# 8         Mohit     89
# 9         Ankit     73
# 10        Priya     91
# 11         Neha     84
# 12        Pooja     79
# 13        Sneha     87
# 14         Riya     93
# 15       Simran     75
# 16        Kavya     82
# 17         Isha     90
# 18        Meera     86
# 19        Aditi     80

# %%
# df.drop('Student_ID',axis=1,inplace=True)  # drop column parmanently

# %%
df=pd.read_csv('Used_Bikes.csv')  # read csv file and create data frame

# %%
df  # print data frame
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head(5)  # print upper 5 data
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail(8)  # print lower 8 data
# Out:
#                        bike_name    price         city  kms_driven  \
# 32640     Hero Passion Pro 100cc  32000.0        Delhi     12000.0
# 32641        Bajaj Avenger 220cc  41000.0        Delhi     20245.0
# 32642         Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643     Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644       TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32645   Bajaj Avenger Street 220  60000.0        Delhi     20373.0
# 32646  Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647         Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner   age  power  brand
# 32640   First Owner   6.0  100.0   Hero
# 32641  Second Owner  11.0  220.0  Bajaj
# 32642  Second Owner  19.0  100.0   Hero
# 32643   First Owner   4.0  100.0   Hero
# 32644   First Owner   9.0  180.0    TVS
# 32645   First Owner   6.0  220.0  Bajaj
# 32646   First Owner  16.0  125.0   Hero
# ...

# %%
df[['brand']]  # print brand access column by name
# Out:
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# 32644            TVS
# 32645          Bajaj
# 32646           Hero
# 32647          Bajaj
#
# [32648 rows x 1 columns]

# %%
df.brand  # print brand access column by name
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: str

# %%
df.bike_name  # print bike name
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: str

# %%
df['owner'].unique()  # unique value  ( no of unique value=nuniqu())
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df[['brand']].value_counts()   #  no of avaliable bike
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# LML                    1
# Yezdi                  1
# Name: count, dtype: int64

# %%
df['brand'].nunique()  # no of unique brand
# Out:
# 23

# %%
df.duplicated()  # is duplicate value avaliable or not
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.drop_duplicates(inplace=True)  # delete duplicate value parmanetly

# %%
df.duplicated().sum()  # no of duplicate value
# Out:
# np.int64(0)

# %%
df.drop_duplicates()  # drop duplicate value  ( not permanently)
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.drop_duplicates(inplace=True)  # delete duplicate value parmanetly

# %%
df.duplicated().sum()  # no of duplicate value
# Out:
# np.int64(0)

# %%
df.isnull() # check null value in data frame
# Out:
#       bike_name  price   city  kms_driven  owner    age  power  brand
# 0         False  False  False       False  False  False  False  False
# 1         False  False  False       False  False  False  False  False
# 2         False  False  False       False  False  False  False  False
# 3         False  False  False       False  False  False  False  False
# 4         False  False  False       False  False  False  False  False
# ...         ...    ...    ...         ...    ...    ...    ...    ...
# 9362      False  False  False       False  False  False  False  False
# 9369      False  False  False       False  False  False  False  False
# 9370      False  False  False       False  False  False  False  False
# 9371      False  False  False       False  False  False  False  False
# 9372      False  False  False       False  False  False  False  False
#
# [7324 rows x 8 columns]

# %%
df.isnull().sum()  # no of null value in each column
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict={'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner or More':4}

# %%
df['owner']=df['owner'].map(owner_dict)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# ...

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
brand_dict={'TVS':1,   'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':4,            'Hero':5,           'Bajaj':6,          'Suzuki':7,
         'Benelli':8,             'KTM':9,        'Mahindra':10,        'Kawasaki':11,
          'Ducati':12,         'Hyosung':13, 'Harley-Davidson':14,            'Jawa':15,
             'BMW':16,          'Indian':17,         'Rajdoot':18,             'LML':19,
           'Yezdi':20,              'MV':21,           'Ideal':22}

# %%
df['brand']=df['brand'].map(brand_dict)  # map brand name to number

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power  brand
# ...

# %%
# df.drop("city",axis=1,inplace=True)  # pramanent remove column city

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power  brand
# ...

# %%
df.drop(['city','bike_name'],axis=1,inplace=True)  # remove column city  and bike name (multiple column)

# %%
df
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0    1.0  3.0  110.0      1
# 1     119900.0     11000.0    1.0  4.0  350.0      2
# 2     600000.0       110.0    1.0  8.0  675.0      3
# 3      65000.0     16329.0    1.0  4.0  180.0      1
# 4      80000.0     10000.0    1.0  3.0  150.0      4
# ...        ...         ...    ...  ...    ...    ...
# 9362   25000.0     48587.0    1.0  8.0  150.0      5
# 9369   35000.0     60000.0    1.0  9.0  220.0      6
# 9370  450000.0      3430.0    1.0  4.0  750.0     14
# 9371  139000.0     21300.0    1.0  4.0  400.0      6
# 9372   80000.0      7127.0    1.0  5.0  220.0      6
#
# [7324 rows x 6 columns]

# %%
df.duplicated().sum()   # check duplicate value in data frame
# Out:
# np.int64(18)

# %%
df.drop_duplicates(inplace=True)  # delete duplicate value parmanetly

# %%
df.duplicated().sum() # check duplicate value in data frame
# Out:
# np.int64(0)

# %%
df.isnull().sum() # no of null value in each column
# Out:
# price          0
# kms_driven     0
# owner         10
# age            0
# power          0
# brand          0
# dtype: int64

# %%
df.dropna(inplace=True)  # drop null value parmanently

# %%
df.isnull().sum()  # no of null value in each column
# Out:
# price         0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df  # display the dataframe
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0    1.0  3.0  110.0      1
# 1     119900.0     11000.0    1.0  4.0  350.0      2
# 2     600000.0       110.0    1.0  8.0  675.0      3
# 3      65000.0     16329.0    1.0  4.0  180.0      1
# 4      80000.0     10000.0    1.0  3.0  150.0      4
# ...        ...         ...    ...  ...    ...    ...
# 9362   25000.0     48587.0    1.0  8.0  150.0      5
# 9369   35000.0     60000.0    1.0  9.0  220.0      6
# 9370  450000.0      3430.0    1.0  4.0  750.0     14
# 9371  139000.0     21300.0    1.0  4.0  400.0      6
# 9372   80000.0      7127.0    1.0  5.0  220.0      6
#
# [7296 rows x 6 columns]

# %%
x=df.drop('price',axis=1)  # drop column price and store in x

# %%
x          # display the modified dataframe
# Out:
#       kms_driven  owner  age  power  brand
# 0        17654.0    1.0  3.0  110.0      1
# 1        11000.0    1.0  4.0  350.0      2
# 2          110.0    1.0  8.0  675.0      3
# 3        16329.0    1.0  4.0  180.0      1
# 4        10000.0    1.0  3.0  150.0      4
# ...          ...    ...  ...    ...    ...
# 9362     48587.0    1.0  8.0  150.0      5
# 9369     60000.0    1.0  9.0  220.0      6
# 9370      3430.0    1.0  4.0  750.0     14
# 9371     21300.0    1.0  4.0  400.0      6
# 9372      7127.0    1.0  5.0  220.0      6
#
# [7296 rows x 5 columns]

# %%
y=df[['price']]   # select column price and store in y

# %%
y     # display the modified dataframe
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7296 rows x 1 columns]
