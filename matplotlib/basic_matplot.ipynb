# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Matplotlib :-
# Matplotlib is a popular Python library used for creating data visualizations such as line charts, bar charts, pie charts, scatter plots, histograms, and more. It helps present data in a graphical form, making it easier to analyze and understand.
#
#                 Features
# * Creates a wide variety of plots and charts.
# * Easy to use with NumPy and pandas.
# * Highly customizable (titles, labels, colors, legends, etc.).
# * Suitable for both simple and advanced visualizations.
#
#         The code displays a line graph where:
# * The X-axis contains the values 1, 2, 3, 4, 5.
# * The Y-axis contains the values 10, 20, 15, 30, 25.
# * The line connects the data points to show the trend.
#
#         Other Common Plots in Matplotlib
# * Line Plot – Shows trends over time or ordered data.
# * Bar Chart – Compares values across categories.
# * Scatter Plot – Shows the relationship between two variables.
# * Histogram – Displays the distribution of numerical data.
# * Pie Chart – Shows proportions or percentages of a whole.

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
print(xpoint)
print(ypoint)
print(type(xpoint))
print(type(xpoint))
# Out:
# [1 2 3 4]
# [2 4 6 8]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint)     # Plot the line
plt.show()                  # Display the plot

# %%
xpoint=np.array([1,2,3,4])
plt.plot(xpoint)
plt.show()

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint,"o")    # o for dots
plt.show()

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint,"*")    # * for star
plt.show()

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint,marker="*")   # marker="*" for star
plt.show()

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint,marker="*", ms=15)   #  ms = marker size
plt.show()

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint,marker="*", ms=15, mfc="red")    # mfc = marker face color
plt.show()

# %%
xpoint=np.array([1,2,3,4])
ypoint=np.array([2,4,6,8])
plt.plot(xpoint,ypoint,marker="*", ms=15, mfc= "black", mec="red")  # mec = marker edge color
plt.show()

# %%
ypoint=np.array([2,4,6,8])
plt.plot(ypoint,ls="dotted")  # ls = line style
plt.show()

# %%
ypoint=np.array([2,4,6,8])
xpoint=np.array([1,5,7,9])
plt.plot(ypoint)
plt.plot(xpoint)
plt.show()

# %%
ypoint=np.array([2,4,6,8])
xpoint=np.array([1,5,7,9])
plt.ylabel("wcss")   # y-axis label
plt.xlabel("weight")    # x-axis label
plt.title("Elbow method")    # title of the graph
plt.plot(ypoint,xpoint)    # plot the graph
plt.show()

# %%
ypoint=np.array([2,4,6,8])
xpoint=np.array([1,5,7,9])
plt.bar(ypoint,xpoint, color=['red',"blue","green","black"])   # bar graph color parameter
# Out:
# <BarContainer object of 4 artists>

# %%
ypoint=np.array([2,4,6,8])
xpoint=np.array([1,5,7,9])
plt.ylabel("wcss")
plt.xlabel("weight")
plt.title("Elbow method")

plt.bar(ypoint,xpoint, color="red",width=0.5)    # width = width of the bar
# Out:
# <BarContainer object of 4 artists>

# %%
ypoint=np.array([2,4,6,8])
xpoint=np.array([1,5,7,9])
plt.ylabel("weight")
plt.xlabel("wcss")
plt.title("Elbow method")

plt.barh(ypoint,xpoint, color="red")    # barh = horizontal bar graph
# Out:
# <BarContainer object of 4 artists>

# %%
arr= np.random.normal(170,10,175)  # Generate random data with mean=170, std=10, size=175

# %%
arr
# Out:
# array([158.02219851, 173.03078207, 185.01260713, 161.39647231,
#        175.04690436, 175.71724547, 178.63072528, 176.70939208,
#        171.42965012, 169.48478353, 181.36853666, 158.82781068,
#        175.0766294 , 176.49614088, 174.05949903, 171.53773041,
#        154.48610844, 157.12255364, 158.14100578, 180.34408536,
#        179.54233854, 176.33093428, 174.47010416, 186.82536633,
#        161.65905518, 152.73707985, 171.56314213, 181.3237304 ,
#        170.45036525, 163.05175705, 162.54195388, 160.72741789,
#        162.11730859, 176.19314411, 154.87578812, 168.85430232,
#        168.68440691, 151.43217346, 162.51492213, 164.58612744,
#        171.05813697, 190.39154602, 164.99136175, 168.95923603,
#        166.32541582, 152.05355606, 175.48546799, 187.68764999,
#        160.40170854, 158.89180771, 164.52672897, 179.16334992,
#        166.80524504, 157.82639024, 175.31449125, 173.65384245,
#        156.39472759, 173.2050335 , 161.70689674, 171.58211287,
# ...

# %%
plt.hist(arr)   # hist = histogram
# Out:
# (array([ 2.,  8., 23., 27., 31., 36., 29.,  9.,  7.,  3.]),
#  array([145.8880241 , 150.81823272, 155.74844134, 160.67864996,
#         165.60885858, 170.5390672 , 175.46927583, 180.39948445,
#         185.32969307, 190.25990169, 195.19011031]),
#  <BarContainer object of 10 artists>)

# %%
arr=np.array([1,3,5,7,2,4,6,8])
arr2=np.array([2,4,6,8,1,3,5,7])
plt.scatter(arr,arr2)    # Create a scatter plot
plt.show()

# %%
x=np.array([5,7,9,12,23,43,45,67,89,90])
y=np.array([7,9,40,23,43,45,67,89,90,100])
sizes=np.array([20,30,40,50,60,70,80,90,100,110])      # sizes = size of the dots
c=np.array(['red','blue','green','yellow','black','orange','purple','pink','brown','gray'])   # c = color of the dots
plt.scatter(x,y,s=sizes,c=c)   # Create a scatter plot with specified sizes and colors
plt.show()

# %%
x=np.array([5,7,9,12,23,43,45,67,89,90])
y=np.array([7,9,12,23,43,45,67,89,90,100])
sizes=np.array([20,30,40,50,60,70,80,90,100,110])
c=np.array(['red','blue','green','yellow','black','orange','purple','pink','brown','gray'])   # c = color of the dots
plt.scatter(x,y,s=sizes,c=c,alpha=0.5)  # Set transparency to 50%
plt.show()

# %%
x=np.array([5,7,9,12,23,43,45,67,89,90])
y=np.array([7,9,12,23,43,45,67,89,90,100])
sizes=np.array([20,30,40,50,60,70,80,90,100,110])
c=np.array(['red','blue','green','yellow','black','orange','purple','pink','brown','gray'])
plt.scatter(x,y,s=sizes,c=c,cmap='coolwarm')  # Use a colormap for the colors
plt.colorbar()  # Show color scale
plt.show()
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_21132\647328200.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,s=sizes,c=c,cmap='coolwarm')  # Use a colormap for the colors

# %%
x=np.array([5,7,9,12,23,43,45,67,89,90])
y=np.array([7,9,12,23,43,45,67,89,90,100])
sizes=np.array([20,30,40,50,60,70,80,90,100,110])
c=np.array(['red','blue','green','yellow','black','orange','purple','pink','brown','gray'])
plt.scatter(x,y,s=sizes,c=c)
plt.ylabel("wcss")
plt.xlabel("weight")
plt.title("Elbow method")
plt.show()

# %%
datapoint=np.array([5,7,9,12,23,43,45,67,89,90])
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']    # labels for each slice of the pie chart
plt.pie(datapoint,labels=labels)    # Create a pie chart with specified labels
plt.show()

# %%
datapoint=np.array([5,7,9,12])
labels = ['A', 'B', 'C', 'D']    # labels for each slice of the pie chart
eplode_dat=[0,0.2,0,0]      # explode_dat = list that specifies how much each slice of the pie chart should be "exploded" or offset from the center. In this case, the second slice (B) will be offset by 0.2 units, while the other slices will remain in their default positions.
plt.pie(datapoint,labels=labels,explode=eplode_dat)   # Create a pie chart with specified labels and explode values
plt.show()

# %%
datapoint=np.array([5,7,9,12])
labels = ['A', 'B', 'C', 'D']
eplode_dat=[0,0.2,0,0]
plt.pie(datapoint,labels=labels,explode=eplode_dat,shadow=True)
plt.show()

# %%
datapoint=np.array([5,7,9,12])
labels = ['A', 'B', 'C', 'D']
eplode_dat=[0,0.2,0,0]
plt.pie(datapoint,labels=labels,explode=eplode_dat,shadow=True,autopct='%1.1f%%')  #  autopct Show percentage values
plt.legend()  # Show legend (labels)
plt.show()

# %%
df=pd.read_csv(r"C:\Users\rehan\OneDrive\Desktop\Data Science\6-Months-Data-Science\pandas\Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
plt.hist(df['price'])   # Create a histogram of the 'price' column in the DataFrame
# Out:
# (array([3.0922e+04, 8.7400e+02, 7.3500e+02, 4.9000e+01, 3.6000e+01,
#         9.0000e+00, 8.0000e+00, 1.2000e+01, 1.0000e+00, 2.0000e+00]),
#  array([   4400.,  193960.,  383520.,  573080.,  762640.,  952200.,
#         1141760., 1331320., 1520880., 1710440., 1900000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['owner'],df['price'])    # Create a bar graph with 'owner' on the x-axis and 'price' on the y-axis
# Out:
# <BarContainer object of 32648 artists>

# %%
plt.bar(df['age'],df['price'])
# Out:
# <BarContainer object of 32648 artists>

# %% [markdown]
# #### Graph
#         used bike.csv graph

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 1. Load the dataset
# Replace 'Used_Bikes.csv' with your actual file path if it's stored elsewhere
df=pd.read_csv(r"C:\Users\rehan\OneDrive\Desktop\Data Science\6-Months-Data-Science\pandas\Used_Bikes.csv")


# 2. Data Cleaning: Drop exact duplicates to avoid skewed visualizations
df = df.drop_duplicates()

# 3. Filter for the Top 5 most frequent brands for a cleaner plot
top_brands = df["brand"].value_counts().nlargest(5).index
df_filtered = df[df["brand"].isin(top_brands)]

# 4. Set up the matplotlib figure
plt.figure(figsize=(12, 7))
sns.set_theme(style="whitegrid")

# 5. Create a scatter plot with a trend line (lmplot equivalent via regplot/scatterplot)
# We limit the price to 300,000 to focus on the bulk of the data
sns.scatterplot(
    data=df_filtered,
    x="age",
    y="price",
    hue="brand",
    alpha=0.6,
    palette="deep",
    s=50,
)

# 6. Customize the chart labels and formatting
plt.title(
    "Impact of Bike Age on Price (Top 5 Brands)", fontsize=16, fontweight="bold"
)
plt.xlabel("Age of the Bike (Years)", fontsize=12)
plt.ylabel("Price (INR)", fontsize=12)
plt.xlim(0, 15)  # Focus on bikes under 15 years old
plt.ylim(0, 300000)  # Focus on the most common price range

# Format the y-axis with commas for better readability
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f"{int(x):,}"))

# Adjust legend position so it doesn't block data points
plt.legend(title="Brand", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()

# 7. Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 1. Load the dataset
df = pd.read_csv(r"C:\Users\rehan\OneDrive\Desktop\Data Science\6-Months-Data-Science\pandas\Used_Bikes.csv")
df = df.drop_duplicates()

# 2. Set up the matplotlib figure
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")

# 3. Create a boxplot of Price vs Owner Type
# 'showfliers=False' keeps the focus on the main distribution by removing extreme outliers
sns.boxplot(
    data=df,
    x="owner",
    y="price",
    showfliers=False,
    palette="Set2",
    order=["First Owner", "Second Owner", "Third Owner", "Fourth Owner Or More"],
)

# 4. Customize labels and formatting
plt.title(
    "Used Bike Price Distribution by Owner Type", fontsize=15, fontweight="bold"
)
plt.xlabel("Owner Type", fontsize=12)
plt.ylabel("Price (INR)", fontsize=12)

# Format y-axis with commas for readability
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f"{int(x):,}"))

# Rotate x-axis labels slightly so they don't overlap
plt.xticks(rotation=15)

plt.tight_layout()

# 5. Display the graph
plt.show()
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_21132\2576333352.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 1. Load the dataset and remove duplicates
df = pd.read_csv(r"C:\Users\rehan\OneDrive\Desktop\Data Science\6-Months-Data-Science\pandas\Used_Bikes.csv")

df = df.drop_duplicates()

# 2. Filter out rare brands (less than 5 bikes) to ensure clean data
brand_counts = df["brand"].value_counts()
top_brands = brand_counts[brand_counts >= 5].index
df_filtered = df[df["brand"].isin(top_brands)]

# 3. Calculate the median price per brand to order the graph beautifully
brand_order = (
    df_filtered.groupby("brand")["price"]
    .median()
    .sort_values(ascending=False)
    .index
)

# 4. Set up the matplotlib figure
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid")

# 5. Create a horizontal bar plot
sns.barplot(
    data=df_filtered,
    x="price",
    y="brand",
    order=brand_order,
    estimator="median",  # Focuses on the typical price point
    errorbar=None,  # Removes confidence intervals for a cleaner look
    palette="viridis",
)

# 6. Customize labels and formatting
plt.title(
    "Typical (Median) Price by Bike Brand", fontsize=16, fontweight="bold", pad=15
)
plt.xlabel("Median Price (INR)", fontsize=12)
plt.ylabel("Brand", fontsize=12)

# Format the x-axis with commas for better readability
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f"{int(x):,}"))

plt.tight_layout()

# 7. Display the graph
plt.show()
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_21132\3278680970.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 1. Load the dataset and remove duplicates
df = pd.read_csv(r"C:\Users\rehan\OneDrive\Desktop\Data Science\6-Months-Data-Science\pandas\Used_Bikes.csv")

df = df.drop_duplicates()

# 2. Filter data to focus on the main market distribution (helps remove extreme outliers)
df_filtered = df[(df["kms_driven"] <= 100000) & (df["price"] <= 300000)]

# 3. Set up the matplotlib figure
plt.figure(figsize=(11, 6))
sns.set_theme(style="whitegrid")

# 4. Create a scatter plot with low alpha (transparency) to manage overlapping data points
sns.scatterplot(
    data=df_filtered,
    x="kms_driven",
    y="price",
    alpha=0.3,
    color="teal",
    s=30,
)

# 5. Add a linear trendline to visualize the depreciation direction
sns.regplot(
    data=df_filtered,
    x="kms_driven",
    y="price",
    scatter=False,
    color="red",
    line_kws={"linewidth": 2, "linestyle": "--"},
)

# 6. Customize labels and number formatting
plt.title("Bike Price vs. Kilometers Driven", fontsize=15, fontweight="bold", pad=15)
plt.xlabel("Kilometers Driven (kms)", fontsize=12)
plt.ylabel("Price (INR)", fontsize=12)

# Format axes with commas for clean readability
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f"{int(x):,}"))
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f"{int(x):,}"))

plt.tight_layout()

# 7. Display the graph
plt.show()
